# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import pandas as pd
import numpy as np


# File to Load (Remember to Change These)
file_to_load = "population.csv"

# Read Purchasing File and store into Pandas data frame
population = pd.read_csv(file_to_load)
population.head()
# Out:
#    Unnamed: 0                 city_state  census  estimates base  year 2010  \
# 0           0         Abbeville, Alabama    2688            2705       2699
# 1           1         Abbeville, Georgia    2908            2905       2982
# 2           2       Abbeville, Louisiana   12257           12227      12225
# 3           3  Abbeville, South Carolina    5237            5254       5233
# 4           4     Abbeville, Mississippi     419             412        414
#
#    year 2011  year 2012  year 2013  year 2014  year 2015  year 2016  \
# 0       2694       2643       2628       2608       2600       2584
# 1       2951       2932       2933       2862       2929       2767
# 2      12181      12326      12379      12356      12357      12357
# 3       5178       5162       5131       5109       5089       5051
# 4        423        429        428        425        428        423
#
#    year 2017  year 2018  year 2019
# 0       2575       2571       2560
# ...

# %%
#population=population.rename(columns = {'geographic area':'city_state'})

# %%
# pd.Series(['city']).str.replace(' ', regex=True)

# %%
population
# Out:
#        Unnamed: 0                 city_state  census  estimates base  \
# 0               0         Abbeville, Alabama    2688            2705
# 1               1         Abbeville, Georgia    2908            2905
# 2               2       Abbeville, Louisiana   12257           12227
# 3               3  Abbeville, South Carolina    5237            5254
# 4               4     Abbeville, Mississippi     419             412
# ...           ...                        ...     ...             ...
# 19419       19419    Zumbro Falls, Minnesota     207             205
# 19420       19420        Zumbrota, Minnesota    3252            3273
# 19421       19421             Zurich, Kansas      99              99
# 19422       19422              Zwingle, Iowa      91              90
# 19423       19423          Zwolle, Louisiana    1759            1982
#
#        year 2010  year 2011  year 2012  year 2013  year 2014  year 2015  \
# ...

# %%
#population['city_state'] = population.city_state.replace({'city' : ' '}, regex=True)

# %%
#population['city_state'] = population.city_state.replace({'town': ' '}, regex=True)

# %%
#population['city_state'] = population.city_state.replace({'village': ' '}, regex=True)

# %%
#population['city_state'] = population.city_state.replace({'borough': ' '}, regex=True)

# %%
population
# Out:
#                         city_state  census  estimates base  year 2010  \
# 0             Abbeville  , Alabama    2688            2705       2699
# 1             Abbeville  , Georgia    2908            2905       2982
# 2           Abbeville  , Louisiana   12257           12227      12225
# 3      Abbeville  , South Carolina    5237            5254       5233
# 4         Abbeville  , Mississippi     419             412        414
# ...                            ...     ...             ...        ...
# 19419    Zumbro Falls  , Minnesota     207             205        207
# 19420        Zumbrota  , Minnesota    3252            3273       3281
# 19421             Zurich  , Kansas      99              99         99
# 19422              Zwingle  , Iowa      91              90         90
# 19423          Zwolle  , Louisiana    1759            1982       1983
#
#        year 2011  year 2012  year 2013  year 2014  year 2015  year 2016  \
# ...

# %%
#population.to_csv("population.csv")

# %%
#population['city_state'] = population.city_state.replace({'  , ': ', '}, regex=True)

# %%
#population.head()
# Out:
#                    city_state  census  estimates base  year 2010  year 2011  \
# 0         Abbeville , Alabama    2688            2705       2699       2694
# 1         Abbeville , Georgia    2908            2905       2982       2951
# 2       Abbeville , Louisiana   12257           12227      12225      12181
# 3  Abbeville , South Carolina    5237            5254       5233       5178
# 4     Abbeville , Mississippi     419             412        414        423
#
#    year 2012  year 2013  year 2014  year 2015  year 2016  year 2017  \
# 0       2643       2628       2608       2600       2584       2575
# 1       2932       2933       2862       2929       2767       2783
# 2      12326      12379      12356      12357      12357      12246
# 3       5162       5131       5109       5089       5051       5035
# 4        429        428        425        428        423        427
#
#    year 2018  year 2019
# 0       2571       2560
# 1       2800       2684
# ...

# %%
#population.to_csv("population.csv")

# %%
#population['city_state'] = population.city_state.replace({' , ': ', '}, regex=True)

# %%
population
# Out:
#                       city_state  census  estimates base  year 2010  \
# 0             Abbeville, Alabama    2688            2705       2699
# 1             Abbeville, Georgia    2908            2905       2982
# 2           Abbeville, Louisiana   12257           12227      12225
# 3      Abbeville, South Carolina    5237            5254       5233
# 4         Abbeville, Mississippi     419             412        414
# ...                          ...     ...             ...        ...
# 19419    Zumbro Falls, Minnesota     207             205        207
# 19420        Zumbrota, Minnesota    3252            3273       3281
# 19421             Zurich, Kansas      99              99         99
# 19422              Zwingle, Iowa      91              90         90
# 19423          Zwolle, Louisiana    1759            1982       1983
#
#        year 2011  year 2012  year 2013  year 2014  year 2015  year 2016  \
# 0           2694       2643       2628       2608       2600       2584
# ...

# %%
#population.to_csv("population.csv")

# %%
#city_state_df = population['city_state'].apply(lambda x: pd.Series(x.split(',')))

# %%
#city_state_df.head()
# Out:
#            0                1    2
# 0  Abbeville          Alabama  NaN
# 1  Abbeville          Georgia  NaN
# 2  Abbeville        Louisiana  NaN
# 3  Abbeville   South Carolina  NaN
# 4  Abbeville      Mississippi  NaN

# %%
#city_state_df.drop([2], axis=1, inplace=True)

# %%
#city_state_df
# Out:
#                   0                1
# 0         Abbeville          Alabama
# 1         Abbeville          Georgia
# 2         Abbeville        Louisiana
# 3         Abbeville   South Carolina
# 4         Abbeville      Mississippi
# ...             ...              ...
# 19419  Zumbro Falls        Minnesota
# 19420      Zumbrota        Minnesota
# 19421        Zurich           Kansas
# 19422       Zwingle             Iowa
# 19423        Zwolle        Louisiana
#
# [19424 rows x 2 columns]

# %%
#population_concat = pd.concat([city_state_df, population], axis=1)

# %%
#population_concat.head()
# Out:
#            0                1  Unnamed: 0                 city_state  census  \
# 0  Abbeville          Alabama           0         Abbeville, Alabama    2688
# 1  Abbeville          Georgia           1         Abbeville, Georgia    2908
# 2  Abbeville        Louisiana           2       Abbeville, Louisiana   12257
# 3  Abbeville   South Carolina           3  Abbeville, South Carolina    5237
# 4  Abbeville      Mississippi           4     Abbeville, Mississippi     419
#
#    estimates base  year 2010  year 2011  year 2012  year 2013  year 2014  \
# 0            2705       2699       2694       2643       2628       2608
# 1            2905       2982       2951       2932       2933       2862
# 2           12227      12225      12181      12326      12379      12356
# 3            5254       5233       5178       5162       5131       5109
# 4             412        414        423        429        428        425
#
#    year 2015  year 2016  year 2017  year 2018  year 2019
# ...

# %%
#population_concat.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
#population_concat.drop(['city_state'], axis=1, inplace=True)

# %%
#population_concat.head()
# Out:
#            0                1  census  estimates base  year 2010  year 2011  \
# 0  Abbeville          Alabama    2688            2705       2699       2694
# 1  Abbeville          Georgia    2908            2905       2982       2951
# 2  Abbeville        Louisiana   12257           12227      12225      12181
# 3  Abbeville   South Carolina    5237            5254       5233       5178
# 4  Abbeville      Mississippi     419             412        414        423
#
#    year 2012  year 2013  year 2014  year 2015  year 2016  year 2017  \
# 0       2643       2628       2608       2600       2584       2575
# 1       2932       2933       2862       2929       2767       2783
# 2      12326      12379      12356      12357      12357      12246
# 3       5162       5131       5109       5089       5051       5035
# 4        429        428        425        428        423        427
#
#    year 2018  year 2019
# 0       2571       2560
# 1       2800       2684
# ...

# %%
#population_concat = population_concat.rename(columns = {population_concat.columns[0]:'city'})

# %%
#population_concat = population_concat.rename(columns = {population_concat.columns[1]:'state'})

# %%
population_concat.head()
# Out:
#         city            state  census  estimates base  year 2010  year 2011  \
# 0  Abbeville          Alabama    2688            2705       2699       2694
# 1  Abbeville          Georgia    2908            2905       2982       2951
# 2  Abbeville        Louisiana   12257           12227      12225      12181
# 3  Abbeville   South Carolina    5237            5254       5233       5178
# 4  Abbeville      Mississippi     419             412        414        423
#
#    year 2012  year 2013  year 2014  year 2015  year 2016  year 2017  \
# 0       2643       2628       2608       2600       2584       2575
# 1       2932       2933       2862       2929       2767       2783
# 2      12326      12379      12356      12357      12357      12246
# 3       5162       5131       5109       5089       5051       5035
# 4        429        428        425        428        423        427
#
#    year 2018  year 2019
# 0       2571       2560
# 1       2800       2684
# ...

# %%
population_concat.to_csv("population.csv")
